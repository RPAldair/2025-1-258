# %% [markdown]
# # INSPECCION DE DATOS

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.tree import plot_tree

# Cargar datos CSV
csv_path='../data/KRvideos_cc50_202101.csv'
df = pd.read_csv(csv_path)

# Cargar categorías desde JSON
with open('../data/KR_category_id.json', 'r') as f:
    categories = json.load(f)

print(df.head())
print(df.info())
print(df.describe())
print(df['category_id'].value_counts(dropna=False))
# Out:
#       video_id trending_date                       title channel_title  \
# 0  RxGQe4EeEpA      17.14.11          좋아 by 민서_윤종신_좋니 답가        라푸마코리아
# 1  hH7wVE8OlQ0      17.14.11            JSA 귀순 북한군 총격 부상        Edward
# 2  9V8bnWUmE9U      17.14.11  나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)     나몰라패밀리 핫쇼
# 3  0_8py-t5R80      17.14.11  이명박 출국 현장, 놓치면 안되는 장면         미디어몽구
# 4  bk55RbxiQdI      17.14.11     김장겸은 물러갔다 MBC 노조 환호와 눈물        NocutV
#
#    category_id     publish_time  \
# 0         22.0  13/11/2017 2:07
# 1         25.0  13/11/2017 5:59
# 2         22.0  11/11/2017 2:16
# 3         25.0  12/11/2017 6:19
# 4         25.0  13/11/2017 6:08
#
#                                                 tags     views   likes  \
# 0                      라푸마|"윤종신"|"좋니"|"좋아"|"샬레"|"민서"  156130.0  1422.0
# 1        JSA|"귀순"|"북한군"|"총격"|"부상"|"JSA 귀순 북한군 총격 부상"   76533.0   211.0
# 2                아디다스|"빼빼로"|"핫쇼"|"나몰라패밀리"|"대학로"|"공연"  421409.0  5112.0
# 3  이명박|"이명박 출국금지"|"이명박 출국현장"|"이명박 바레인"|"이명박 대통령"|...  222850.0  2093.0
# 4          nocutV|"노컷V"|"CBS"|"mbc"|"김장겸"|"해임"|"허일후"   84466.0  1094.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      40.0          272.0  https://i.ytimg.com/vi/RxGQe4EeEpA/default.jpg
# 1      28.0          113.0  https://i.ytimg.com/vi/hH7wVE8OlQ0/default.jpg
# 2     166.0          459.0  https://i.ytimg.com/vi/9V8bnWUmE9U/default.jpg
# 3     173.0         1219.0  https://i.ytimg.com/vi/0_8py-t5R80/default.jpg
# 4     109.0          450.0  https://i.ytimg.com/vi/bk55RbxiQdI/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             FALSO            FALSO                  FALSO
# 1             FALSO            FALSO                  FALSO
# 2             FALSO            FALSO                  FALSO
# 3             FALSO            FALSO                  FALSO
# 4             FALSO            FALSO                  FALSO
#
#                                          description               state  \
# 0  윤종신 '좋니'의 답가 '좋아' 최초 공개!\n그 여자의 이야기를 지금 만나보세요....    Taegu Gwangyoksi
# 1  [채널A단독]北 병사 현재 '의식불명'… 혈압 떨어지는 중 \n[채널A단독]우리측 ...             Daejeon
# 2                                    퍼가실때 꼭 출처 부탁드려요   Chungcheongbuk Do
# 3                                다스는 누구겁니까 듣고 난 후 표정  Kwangju Gwangyoksi
# 4  김장겸 MBC 사장이 결국 해임됐다.\n\nMBC 대주주인 방송문화진흥회는 13일 ...   Chungcheongbuk Do
#
#          lat         lon                         geometry
# 0  35.866789  128.606971  POINT (128.6069714 35.86678876)
# 1  36.335546  127.425028   POINT (127.425028 36.33554567)
# 2  36.935251  127.689715  POINT (127.6897147 36.93525067)
# 3  35.170966  126.910434   POINT (126.9104341 35.1709656)
# 4  36.935251  127.689715  POINT (127.6897147 36.93525067)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36897 entries, 0 to 36896
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                36741 non-null  object
#  1   trending_date           34730 non-null  object
#  2   title                   34592 non-null  object
#  3   channel_title           34575 non-null  object
#  4   category_id             34567 non-null  float64
#  5   publish_time            34567 non-null  object
#  6   tags                    34568 non-null  object
#  7   views                   34567 non-null  float64
#  8   likes                   34567 non-null  float64
#  9   dislikes                34567 non-null  float64
#  10  comment_count           34567 non-null  float64
#  11  thumbnail_link          34568 non-null  object
#  12  comments_disabled       34567 non-null  object
#  13  ratings_disabled        34567 non-null  object
#  14  video_error_or_removed  34567 non-null  object
#  15  description             31404 non-null  object
#  16  state                   36897 non-null  object
#  17  lat                     36897 non-null  float64
#  18  lon                     36897 non-null  float64
#  19  geometry                36897 non-null  object
# dtypes: float64(7), object(13)
# memory usage: 5.6+ MB
# None
#         category_id         views         likes      dislikes  comment_count  \
# count  34567.000000  3.456700e+04  3.456700e+04  3.456700e+04   3.456700e+04
# mean      21.137675  4.249473e+05  1.218642e+04  5.390980e+02   2.025383e+03
# std        6.675455  2.430637e+06  1.170531e+05  1.370852e+04   2.150677e+04
# min        1.000000  2.050000e+03  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       22.000000  4.776850e+04  4.120000e+02  2.100000e+01   1.050000e+02
# 50%       24.000000  1.114960e+05  1.389000e+03  6.500000e+01   3.450000e+02
# 75%       25.000000  2.788665e+05  3.704500e+03  1.750000e+02   9.290000e+02
# max       44.000000  1.138762e+08  5.150839e+06  1.470388e+06   1.142274e+06
#
#                 lat           lon
# count  36897.000000  36897.000000
# mean      35.988036    127.767228
# std        1.136405      0.938696
# min       33.510137    126.521931
# 25%       35.170966    126.910434
# 50%       35.866789    127.689715
# 75%       37.348068    128.606971
# max       37.566349    129.316954
# category_id
# 24.0    8955
# 25.0    7582
# 22.0    7056
# NaN     2330
# 1.0     2200
# 23.0    2056
# 10.0    1825
# 20.0    1392
# 17.0     936
# 15.0     735
# 26.0     558
# 27.0     486
# 29.0     288
# 43.0     165
# 2.0      120
# 28.0     115
# 19.0      96
# 44.0       2
# Name: count, dtype: int64

# %% [markdown]
# ### 1. Unificacion de archivos

# %%
categories_list = []
for item in categories['items']:
    categories_list.append({
        'category_id': int(item['id']),
        'category_name': item['snippet']['title']
    })

categories_df = pd.DataFrame(categories_list)

df = df.dropna(subset=['category_id'])
df['category_id'] = df['category_id'].astype(int)

df = df.merge(categories_df, on='category_id', how='left')
print(df.head())
# Out:
#       video_id trending_date                       title channel_title  \
# 0  RxGQe4EeEpA      17.14.11          좋아 by 민서_윤종신_좋니 답가        라푸마코리아
# 1  hH7wVE8OlQ0      17.14.11            JSA 귀순 북한군 총격 부상        Edward
# 2  9V8bnWUmE9U      17.14.11  나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)     나몰라패밀리 핫쇼
# 3  0_8py-t5R80      17.14.11  이명박 출국 현장, 놓치면 안되는 장면         미디어몽구
# 4  bk55RbxiQdI      17.14.11     김장겸은 물러갔다 MBC 노조 환호와 눈물        NocutV
#
#    category_id     publish_time  \
# 0           22  13/11/2017 2:07
# 1           25  13/11/2017 5:59
# 2           22  11/11/2017 2:16
# 3           25  12/11/2017 6:19
# 4           25  13/11/2017 6:08
#
#                                                 tags     views   likes  \
# 0                      라푸마|"윤종신"|"좋니"|"좋아"|"샬레"|"민서"  156130.0  1422.0
# 1        JSA|"귀순"|"북한군"|"총격"|"부상"|"JSA 귀순 북한군 총격 부상"   76533.0   211.0
# 2                아디다스|"빼빼로"|"핫쇼"|"나몰라패밀리"|"대학로"|"공연"  421409.0  5112.0
# 3  이명박|"이명박 출국금지"|"이명박 출국현장"|"이명박 바레인"|"이명박 대통령"|...  222850.0  2093.0
# 4          nocutV|"노컷V"|"CBS"|"mbc"|"김장겸"|"해임"|"허일후"   84466.0  1094.0
#
#    dislikes  ...                                  thumbnail_link  \
# 0      40.0  ...  https://i.ytimg.com/vi/RxGQe4EeEpA/default.jpg
# 1      28.0  ...  https://i.ytimg.com/vi/hH7wVE8OlQ0/default.jpg
# 2     166.0  ...  https://i.ytimg.com/vi/9V8bnWUmE9U/default.jpg
# 3     173.0  ...  https://i.ytimg.com/vi/0_8py-t5R80/default.jpg
# 4     109.0  ...  https://i.ytimg.com/vi/bk55RbxiQdI/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             FALSO            FALSO                  FALSO
# 1             FALSO            FALSO                  FALSO
# 2             FALSO            FALSO                  FALSO
# 3             FALSO            FALSO                  FALSO
# 4             FALSO            FALSO                  FALSO
#
#                                          description               state  \
# 0  윤종신 '좋니'의 답가 '좋아' 최초 공개!\n그 여자의 이야기를 지금 만나보세요....    Taegu Gwangyoksi
# 1  [채널A단독]北 병사 현재 '의식불명'… 혈압 떨어지는 중 \n[채널A단독]우리측 ...             Daejeon
# 2                                    퍼가실때 꼭 출처 부탁드려요   Chungcheongbuk Do
# 3                                다스는 누구겁니까 듣고 난 후 표정  Kwangju Gwangyoksi
# 4  김장겸 MBC 사장이 결국 해임됐다.\n\nMBC 대주주인 방송문화진흥회는 13일 ...   Chungcheongbuk Do
#
#          lat         lon                         geometry    category_name
# 0  35.866789  128.606971  POINT (128.6069714 35.86678876)   People & Blogs
# 1  36.335546  127.425028   POINT (127.425028 36.33554567)  News & Politics
# 2  36.935251  127.689715  POINT (127.6897147 36.93525067)   People & Blogs
# 3  35.170966  126.910434   POINT (126.9104341 35.1709656)  News & Politics
# 4  36.935251  127.689715  POINT (127.6897147 36.93525067)  News & Politics
#
# [5 rows x 21 columns]

# %% [markdown]
# # Visualizacion de datos

# %% [markdown]
# ### 1. Visualizar cantidad de valores nulos por columna

# %%
nulos = df.isnull().sum()
nulos_percent = (nulos / len(df)) * 100
nulos_df = pd.DataFrame({'Nulos': nulos, '% Nulos': nulos_percent})

print("Resumen de valores nulos por columna:")
print(nulos_df)

# Gráfico de barras para visualizar nulos
plt.figure(figsize=(10,6))
sns.barplot(x=nulos_df.index, y='Nulos', data=nulos_df)
plt.xticks(rotation=45)
plt.title('Cantidad de valores nulos por columna')
plt.ylabel('Cantidad de nulos')
plt.xlabel('Columnas')
plt.tight_layout()
plt.show()
# Out:
# Resumen de valores nulos por columna:
#                         Nulos   % Nulos
# video_id                    0  0.000000
# trending_date               0  0.000000
# title                       0  0.000000
# channel_title               0  0.000000
# category_id                 0  0.000000
# publish_time                0  0.000000
# tags                        0  0.000000
# views                       0  0.000000
# likes                       0  0.000000
# dislikes                    0  0.000000
# comment_count               0  0.000000
# thumbnail_link              0  0.000000
# comments_disabled           0  0.000000
# ratings_disabled            0  0.000000
# video_error_or_removed      0  0.000000
# description              3163  9.150346
# state                       0  0.000000
# lat                         0  0.000000
# lon                         0  0.000000
# geometry                    0  0.000000
# category_name             288  0.833165

# %% [markdown]
# ### 2. Tabla resumen de estadísticas para columnas numéricas

# %%
print("Primeras filas de 'category_id' y 'category_name':")
print(df[['category_id', 'category_name']].head())
# Out:
# Primeras filas de 'category_id' y 'category_name':
#    category_id    category_name
# 0           22   People & Blogs
# 1           25  News & Politics
# 2           22   People & Blogs
# 3           25  News & Politics
# 4           25  News & Politics

# %% [markdown]
# ### 3. Verificar que no hayan valores negativos en: (likes, dislikes, views)

# %%
#verificamos si hay negativos debido a que como no deberian haber negativos, esto seria un error
cols_num = ['views', 'likes', 'dislikes']
for col in cols_num:
    fuera_rango = df[df[col] < 0]
    if len(fuera_rango) > 0:
        print(f"Valores fuera de rango encontrados en '{col}':")
        print(fuera_rango[[col]])
    else:
        print(f"No se encontraron valores fuera de rango en '{col}'.")
# Out:
# No se encontraron valores fuera de rango en 'views'.
# No se encontraron valores fuera de rango en 'likes'.
# No se encontraron valores fuera de rango en 'dislikes'.

# %% [markdown]
# ### 4. Visualización de la cantidad de videos por categoría

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='category_name', order=df['category_name'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Cantidad de videos por categoría')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de videos')
plt.tight_layout()
plt.show()

#Tabla de conteo para el grafico
category_counts = df['category_name'].value_counts()
print("Cantidad de videos por categoría:")
print(category_counts)
# Out:
# Cantidad de videos por categoría:
# category_name
# Entertainment           8955
# News & Politics         7582
# People & Blogs          7056
# Film & Animation        2200
# Comedy                  2056
# Music                   1825
# Gaming                  1392
# Sports                   936
# Pets & Animals           735
# Howto & Style            558
# Education                486
# Shows                    165
# Autos & Vehicles         120
# Science & Technology     115
# Travel & Events           96
# Trailers                   2
# Name: count, dtype: int64

# %% [markdown]
# ### 5. Distribución de videos por estado

# %%
state_counts = df['state'].value_counts().reset_index()
state_counts.columns = ['state', 'count']

print(state_counts)

plt.figure(figsize=(10,5))
sns.barplot(data=state_counts, x='state', y='count')
plt.title('Distribución de videos por estado')
plt.xlabel('Estado')
plt.ylabel('Cantidad de videos')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#                  state  count
# 0                Ulsan   2378
# 1     Gyeongsangnam Do   2375
# 2                Busan   2349
# 3     Taegu Gwangyoksi   2344
# 4         Jeollabuk Do   2340
# 5           Gangwon Do   2328
# 6                 Jeju   2317
# 7               Seoul    2295
# 8              Daejeon   2287
# 9    Chungcheongbuk Do   2276
# 10  Kwangju Gwangyoksi   2271
# 11         Gyeonggi Do   2270
# 12             Gwangju   2262
# 13  Inch'on Gwangyoksi   2243
# 14               Daegu   2232

# %% [markdown]
# ### 6. Distribución de videos por estado

# %%
# Tabla de frecuencia
comments_disabled_counts = df['comments_disabled'].value_counts().reset_index()
comments_disabled_counts.columns = ['comments_disabled', 'count']

print(comments_disabled_counts)

# Gráfico
plt.figure(figsize=(6,4))
sns.barplot(data=comments_disabled_counts, x='comments_disabled', y='count', palette='pastel')
plt.title('Videos con comentarios deshabilitados')
plt.xlabel('Comentarios deshabilitados')
plt.ylabel('Cantidad')
plt.tight_layout()
plt.show()
# Out:
#   comments_disabled  count
# 0             FALSO  34056
# 1         VERDADERO    511
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\1291010831.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=comments_disabled_counts, x='comments_disabled', y='count', palette='pastel')

# %% [markdown]
# ### Los 5 canales los cuales son tendencia y 5 que estan con menos frecuencia

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

videos_por_canal = df.groupby('channel_title').size().reset_index(name='cantidad_videos_tendencia')
top_5 = videos_por_canal.sort_values(by='cantidad_videos_tendencia', ascending=False).head(5)

bottom_5 = videos_por_canal[videos_por_canal['cantidad_videos_tendencia'] > 0].sort_values(by='cantidad_videos_tendencia').head(5)

#Gráfico Top 5
plt.figure(figsize=(12,5))
sns.barplot(data=top_5, x='cantidad_videos_tendencia', y='channel_title', palette='Greens_d')
plt.title('Top 5 canales con más videos en tendencia')
plt.xlabel('Cantidad de videos en tendencia')
plt.ylabel('Canal')
plt.tight_layout()
plt.show()

#Gráfico Bottom 5
plt.figure(figsize=(12,5))
sns.barplot(data=bottom_5, x='cantidad_videos_tendencia', y='channel_title', palette='Reds_d')
plt.title('Top 5 canales con menos videos en tendencia (con al menos 1 video)')
plt.xlabel('Cantidad de videos en tendencia')
plt.ylabel('Canal')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\3674372352.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5, x='cantidad_videos_tendencia', y='channel_title', palette='Greens_d')
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\3674372352.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_5, x='cantidad_videos_tendencia', y='channel_title', palette='Reds_d')

# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# ### 1. Evaluación de duplicados y nulos

# %%
df_out = df.copy()
df_num = df.select_dtypes(include='number')

categoricas = df.select_dtypes(include=['object'])

# %%
df_num.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count  \
# count  34567.000000  3.456700e+04  3.456700e+04  3.456700e+04   3.456700e+04
# mean      21.137675  4.249473e+05  1.218642e+04  5.390980e+02   2.025383e+03
# std        6.675455  2.430637e+06  1.170531e+05  1.370852e+04   2.150677e+04
# min        1.000000  2.050000e+03  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       22.000000  4.776850e+04  4.120000e+02  2.100000e+01   1.050000e+02
# 50%       24.000000  1.114960e+05  1.389000e+03  6.500000e+01   3.450000e+02
# 75%       25.000000  2.788665e+05  3.704500e+03  1.750000e+02   9.290000e+02
# max       44.000000  1.138762e+08  5.150839e+06  1.470388e+06   1.142274e+06
#
#                 lat           lon
# count  34567.000000  34567.000000
# mean      35.989816    127.768105
# std        1.136712      0.939118
# min       33.510137    126.521931
# 25%       35.170966    126.910434
# 50%       35.866789    127.689715
# 75%       37.348068    128.606971
# max       37.566349    129.316954

# %%
categoricas.describe()
# Out:
#        video_id trending_date        title channel_title     publish_time  \
# count     34567         34567        34567         34567            34567
# unique    15876           205        16353          4043            14548
# top      #NAME?      18.20.05  브베 실시간 스트리밍          신의한수  29/01/2018 4:00
# freq        443           200           20           222               25
#
#           tags                                  thumbnail_link  \
# count    34567                                           34567
# unique   10791                                           16089
# top     [none]  https://i.ytimg.com/vi/AKDuAzSwaPI/default.jpg
# freq      7183                                              10
#
#        comments_disabled ratings_disabled video_error_or_removed description  \
# count              34567            34567                  34567       31404
# unique                 2                2                      2       12890
# top                FALSO            FALSO                  FALSO          설명
# freq               34056            33167                  34526         150
#
#         state                         geometry  category_name
# count   34567                            34567          34279
# unique     15                               15             16
# top     Ulsan  POINT (129.3169539 35.54673077)  Entertainment
# freq     2378                             2378           8955

# %% [markdown]
# ### 2. Mapa de calor de valores faltantes en variables

# %%
df.isin(["", "NA", "[none]"]).sum()
df.replace(["", "NA", "[none]"], np.nan, inplace=True)

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.title("Mapa de calor de valores faltantes")
plt.show()

# %% [markdown]
# ### 3. Ver la cantidad de duplicados

# %%
duplicados = df[df.duplicated(keep=False)]
duplicados
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, comments_disabled, ratings_disabled, video_error_or_removed, description, state, lat, lon, geometry, category_name, days_to_trending]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### 3.1 Eliminar los duplicados

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### 4.  Conversión de fechas y antigüedad del video

# %%
df['publish_time'] = pd.to_datetime(df['publish_time'], errors='coerce')
df['trending_date'] = pd.to_datetime(df['trending_date'], errors='coerce')
df['days_to_trending'] = (df['trending_date'] - df['publish_time']).dt.days

# %% [markdown]
# ### 5. Función para mostrar % de nulos

# %%
def fx_porc_missings(data, only_missings = False):
    df_vars_missings = pd.concat([
        pd.DataFrame(data.isnull().sum(), columns = ['n_nulos']),
        pd.DataFrame(100*data.isnull().sum()/len(data), columns = ['%Total'])
    ], axis=1)
    if only_missings:
        return df_vars_missings[df_vars_missings["n_nulos"] != 0]
    else:
        return df_vars_missings

# %% [markdown]
# ### 5.1 Mostrando nulos

# %%
fx_porc_missings(df, only_missings=True)
# Out:
#                   n_nulos     %Total
# trending_date       21487  62.462209
# tags                 7141  20.758721
# description          3148   9.151163
# category_name         286   0.831395
# days_to_trending    21487  62.462209

# %% [markdown]
# ### 6. Validación de lógica de registros

# %%
df = df[df['likes'] <= df['views']]

# %% [markdown]
# ### 7.  Tratamiento de valores nulos

# %%
# Imputar nulos
df['tags'] = df['tags'].fillna("Sin etiquetas")
df['comment_count'] = df['comment_count'].fillna(df['comment_count'].median())
df['views'] = df['views'].fillna(df['views'].median())
df['category_name'] = df['category_name'].fillna(df['category_name'].mode()[0])
df['category_name_encoded'] = LabelEncoder().fit_transform(df['category_name'])
df['description']=df['description'].fillna("Sin descripción")
# Eliminar filas con 0 views para evitar divisiones por cero
df = df.loc[df['views'] > 0].copy()

# %% [markdown]
# ### 8. Detección de tratamiento outliers

# %%
def marcar_outliers(col):
    Q1 = df_num[col].quantile(0.25)
    Q3 = df_num[col].quantile(0.75)
    IQR = Q3 - Q1
    lim_inf = Q1 - 1.5 * IQR
    lim_sup = Q3 + 1.5 * IQR
    return (df[col] < lim_inf) | (df[col] > lim_sup)

for col in df_num.columns:
    flag_col = f"outlier_{col}"
    df_out[flag_col] = marcar_outliers(col)

# Cuántos outliers hay por columna
df_out.filter(like='outlier_').sum()
# Out:
# outlier_category_id      5953
# outlier_views            3784
# outlier_likes            3520
# outlier_dislikes         3921
# outlier_comment_count    3601
# outlier_lat                 0
# outlier_lon                 0
# dtype: object

# %%
df['views'].sort_values(ascending=False).head(10)
Q1 = df['views'].quantile(0.25)
Q3 = df['views'].quantile(0.75)
IQR = Q3 - Q1
lim_sup = Q3 + 1.5 * IQR
df[df['views'] > lim_sup].describe()
# Out:
#                        trending_date  category_id  \
# count                           1400  3784.000000
# mean   2005-02-05 22:16:06.857142784    18.516649
# min              2001-01-18 00:00:00     1.000000
# 25%              2002-10-18 00:00:00    10.000000
# 50%              2004-05-18 00:00:00    22.000000
# 75%              2006-03-18 00:00:00    24.000000
# max              2012-12-17 00:00:00    43.000000
# std                              NaN     7.799004
#
#                         publish_time         views         likes  \
# count                           3784  3.784000e+03  3.784000e+03
# mean   2018-02-27 09:00:06.279069952  2.701941e+06  9.162198e+04
# min              2016-02-12 16:56:00  6.256650e+05  0.000000e+00
# 25%              2018-01-10 10:54:45  8.027570e+05  4.328250e+03
# 50%              2018-02-25 06:29:30  1.098268e+06  1.089850e+04
# 75%              2018-04-27 01:05:00  1.860784e+06  3.146450e+04
# max              2018-06-13 14:29:00  1.138762e+08  5.150839e+06
# std                              NaN  6.924240e+06  3.433824e+05
#
#            dislikes  comment_count          lat          lon  \
# count  3.784000e+03   3.784000e+03  3784.000000  3784.000000
# mean   4.039756e+03   1.339532e+04    35.969745   127.790015
# min    0.000000e+00   0.000000e+00    33.510137   126.521931
# 25%    3.370000e+02   1.205000e+03    35.170966   126.910434
# 50%    6.300000e+02   2.428000e+03    35.866789   127.689715
# 75%    1.369000e+03   6.215500e+03    37.348068   128.606971
# max    1.470388e+06   1.142274e+06    37.566349   129.316954
# std    4.126715e+04   6.370818e+04     1.125633     0.946316
#
#        days_to_trending  category_name_encoded
# count       1400.000000            3784.000000
# mean       -4779.689286               5.653013
# min        -6192.000000               0.000000
# 25%        -5591.250000               3.000000
# 50%        -5066.500000               5.000000
# 75%        -4458.000000               8.000000
# max        -1816.000000              15.000000
# std         1155.962230               3.218676

# %%
plt.figure(figsize=(12, 6))
df_num.boxplot()
plt.title("Boxplots de variables numéricas")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9. Winsorización de datos outliers

# %%
for col in df_num.columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lim_inf = Q1 - 1.5 * IQR
    lim_sup = Q3 + 1.5 * IQR
    df[col] = df[col].clip(lower=lim_inf, upper=lim_sup)

# %% [markdown]
# ### 10. Normalización de variables numéricas

# %%
num_cols = ['views', 'likes', 'dislikes', 'comment_count', 'days_to_trending']
scaler = StandardScaler()
df_scaled = df.copy()
df_scaled[num_cols] = scaler.fit_transform(df[num_cols])

# %% [markdown]
# ### 11. Codificación de variables categóricas

# %%
cat_cols = ['category_name', 'channel_title', 'state']
encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    df_scaled[col + '_encoded'] = le.fit_transform(df_scaled[col])
    encoders[col] = le

df_scaled[[col + '_encoded' for col in cat_cols]].head()
# Out:
#    category_name_encoded  channel_title_encoded  state_encoded
# 0                      9                   2526             13
# 1                      8                    419              3
# 2                      9                   2279              1
# 3                      8                   2702             11
# 4                      8                   1068              1

# %%
df_scaled.head()
# Out:
#       video_id trending_date                       title channel_title  \
# 0  RxGQe4EeEpA           NaT          좋아 by 민서_윤종신_좋니 답가        라푸마코리아
# 1  hH7wVE8OlQ0           NaT            JSA 귀순 북한군 총격 부상        Edward
# 2  9V8bnWUmE9U           NaT  나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)     나몰라패밀리 핫쇼
# 3  0_8py-t5R80           NaT  이명박 출국 현장, 놓치면 안되는 장면         미디어몽구
# 4  bk55RbxiQdI           NaT     김장겸은 물러갔다 MBC 노조 환호와 눈물        NocutV
#
#    category_id        publish_time  \
# 0         22.0 2017-11-13 02:07:00
# 1         25.0 2017-11-13 05:59:00
# 2         22.0 2017-11-11 02:16:00
# 3         25.0 2017-11-12 06:19:00
# 4         25.0 2017-11-13 06:08:00
#
#                                                 tags     views     likes  \
# 0                      라푸마|"윤종신"|"좋니"|"좋아"|"샬레"|"민서" -0.205574 -0.403529
# 1        JSA|"귀순"|"북한군"|"총격"|"부상"|"JSA 귀순 북한군 총격 부상" -0.606116 -0.840573
# 2                아디다스|"빼빼로"|"핫쇼"|"나몰라패밀리"|"대학로"|"공연"  1.129342  0.928175
# 3  이명박|"이명박 출국금지"|"이명박 출국현장"|"이명박 바레인"|"이명박 대통령"|...  0.130169 -0.161368
# 4          nocutV|"노컷V"|"CBS"|"mbc"|"김장겸"|"해임"|"허일후" -0.566196 -0.521902
#
#    dislikes  ...                                        description  \
# 0 -0.611857  ...  윤종신 '좋니'의 답가 '좋아' 최초 공개!\n그 여자의 이야기를 지금 만나보세요....
# 1 -0.701826  ...  [채널A단독]北 병사 현재 '의식불명'… 혈압 떨어지는 중 \n[채널A단독]우리측 ...
# 2  0.332816  ...                                    퍼가실때 꼭 출처 부탁드려요
# 3  0.385298  ...                                다스는 누구겁니까 듣고 난 후 표정
# 4 -0.094536  ...  김장겸 MBC 사장이 결국 해임됐다.\n\nMBC 대주주인 방송문화진흥회는 13일 ...
#
#                 state        lat         lon                         geometry  \
# 0    Taegu Gwangyoksi  35.866789  128.606971  POINT (128.6069714 35.86678876)
# 1             Daejeon  36.335546  127.425028   POINT (127.425028 36.33554567)
# 2   Chungcheongbuk Do  36.935251  127.689715  POINT (127.6897147 36.93525067)
# 3  Kwangju Gwangyoksi  35.170966  126.910434   POINT (126.9104341 35.1709656)
# 4   Chungcheongbuk Do  36.935251  127.689715  POINT (127.6897147 36.93525067)
#
#      category_name days_to_trending  category_name_encoded  \
# 0   People & Blogs              NaN                      9
# 1  News & Politics              NaN                      8
# 2   People & Blogs              NaN                      9
# 3  News & Politics              NaN                      8
# 4  News & Politics              NaN                      8
#
#    channel_title_encoded state_encoded
# 0                   2526            13
# 1                    419             3
# 2                   2279             1
# 3                   2702            11
# 4                   1068             1
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 12. Crear variables derivadas

# %%
df['like_ratio'] = df['likes'] / df['views']
df['comment_ratio'] = df['comment_count'] / df['views']

# %% [markdown]
# ### 13. Eliminar columnas irrelevantes (falta determinar cuales se borraran, estas que estan acá creo que podrían ser)

# %%
df.drop(['video_error_or_removed', 'thumbnail_link','days_to_trending','trending_date'], axis=1, inplace=True)

# %% [markdown]
# ### 14. Exportar el dataset limpio

# %%
df.to_csv("../data/KRvideos_limpio.csv", index=False)

# %% [markdown]
# ### 15. Análisis visual posterior a limpieza

# %%
plt.figure(figsize=(12, 6))
df.boxplot()
plt.title("Boxplots de variables numéricas")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 4))
sns.histplot(df['views'], bins=50, color='green')
plt.title("Distribución de vistas")
plt.show()

plt.figure(figsize=(10, 4))
sns.boxplot(x='category_id', y='views', data=df)
plt.title("Boxplot de vistas por categoría")
plt.show()


sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.title("Mapa de calor de valores faltantes")
plt.show()

# %%
print("Cantidad de valores nulos por columna:")
print(df.isnull().sum())
# Out:
# Cantidad de valores nulos por columna:
# video_id                 0
# title                    0
# channel_title            0
# category_id              0
# publish_time             0
# tags                     0
# views                    0
# likes                    0
# dislikes                 0
# comment_count            0
# comments_disabled        0
# ratings_disabled         0
# description              0
# state                    0
# lat                      0
# lon                      0
# geometry                 0
# category_name            0
# category_name_encoded    0
# like_ratio               0
# comment_ratio            0
# dtype: int64

# %%
# Mostrar cantidad de valores nulos solo en columnas numéricas
num_cols = df.select_dtypes(include=[np.number]).columns
print("Valores nulos en variables numéricas:")
print(df[num_cols].isnull().sum())
# Out:
# Valores nulos en variables numéricas:
# category_id              0
# views                    0
# likes                    0
# dislikes                 0
# comment_count            0
# lat                      0
# lon                      0
# category_name_encoded    0
# like_ratio               0
# comment_ratio            0
# dtype: int64

# %% [markdown]
# # Entrenamiento con el modelo Arboles de Regresion para predecir Vistas

# %% [markdown]
# ### 1. Generamos la matriz de correlacion y el heatmap

# %%
df_numeric=df.select_dtypes(include=['number'])
corr_matrix=df_numeric.corr()
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)
# Out:
# c:\Users\rivas\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.draw()
# <Axes: >
# C:\Users\rivas\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   func(*args, **kwargs)
# C:\Users\rivas\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
category_count = df['category_id'].value_counts()
print("Frequency table for Sector:")
print(category_count)
# Out:
# Frequency table for Sector:
# category_id
# 24.0    8923
# 25.0    7532
# 22.0    7023
# 17.5    5786
# 23.0    2045
# 20.0    1387
# 26.0     557
# 27.0     484
# 29.0     286
# 29.5     167
# 28.0     114
# 19.0      96
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Mostramos los graficos de dispersión

# %% [markdown]
# ### 2.1 Grafico likes - views

# %%
sns.lmplot(data=df,x='likes',y='views',height=6,aspect=2,line_kws={'color': 'red'})

# %% [markdown]
# ### 2.2 Grafico dislikes - views

# %%
sns.lmplot(data=df,x='dislikes',y='views',height=6,aspect=2,line_kws={'color': 'red'})

# %% [markdown]
# ### 2.3 Grafico comment_count - views

# %%
sns.lmplot(data=df,x='comment_count',y='views',height=6,aspect=2,line_kws={'color': 'red'})

# %% [markdown]
# ### 2.4 Grafico comment-ratio - views

# %%
sns.lmplot(data=df,x='comment_ratio',y='views',height=6,aspect=2,line_kws={'color': 'red'})
plt.ylim(bottom=0)
# Out:
# c:\Users\rivas\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   self._figure.tight_layout(*args, **kwargs)
# (0.0, 698804.0175600768)

# %% [markdown]
# ### 2.5 Grafico like-ratio - views

# %%
sns.lmplot(data=df,x='like_ratio',y='views',height=6,aspect=2,line_kws={'color': 'red'})
plt.ylim(bottom=0)
# Out:
# c:\Users\rivas\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   self._figure.tight_layout(*args, **kwargs)
# (0.0, 675058.9871448202)

# %%
# Tabla de frecuencia para la variable 'Sector'
category_counts = df['category_name'].value_counts()
print("Frequency table for Sector:")
print(category_counts)
# Out:
# Frequency table for Sector:
# category_name
# Entertainment           9209
# News & Politics         7532
# People & Blogs          7023
# Film & Animation        2187
# Comedy                  2045
# Music                   1816
# Gaming                  1387
# Sports                   932
# Pets & Animals           732
# Howto & Style            557
# Education                484
# Shows                    165
# Autos & Vehicles         119
# Science & Technology     114
# Travel & Events           96
# Trailers                   2
# Name: count, dtype: int64

# %% [markdown]
# ### 2.6 Transformamos la columna Category_name a una variable numerica

# %%
# Realizar One-Hot Encoding en la columna 'category_name'
df_encoded = pd.get_dummies(df, columns=['category_name'], drop_first=True)

# Mostrar las primeras filas del dataframe con la variable codificada
print("DataFrame after One-Hot Encoding:")
display(df_encoded.head())
# Out:
# DataFrame after One-Hot Encoding:
#       video_id                       title channel_title  category_id  \
# 0  RxGQe4EeEpA          좋아 by 민서_윤종신_좋니 답가        라푸마코리아         22.0
# 1  hH7wVE8OlQ0            JSA 귀순 북한군 총격 부상        Edward         25.0
# 2  9V8bnWUmE9U  나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)     나몰라패밀리 핫쇼         22.0
# 3  0_8py-t5R80  이명박 출국 현장, 놓치면 안되는 장면         미디어몽구         25.0
# 4  bk55RbxiQdI     김장겸은 물러갔다 MBC 노조 환호와 눈물        NocutV         25.0
#
#          publish_time                                               tags  \
# 0 2017-11-13 02:07:00                      라푸마|"윤종신"|"좋니"|"좋아"|"샬레"|"민서"
# 1 2017-11-13 05:59:00        JSA|"귀순"|"북한군"|"총격"|"부상"|"JSA 귀순 북한군 총격 부상"
# 2 2017-11-11 02:16:00                아디다스|"빼빼로"|"핫쇼"|"나몰라패밀리"|"대학로"|"공연"
# 3 2017-11-12 06:19:00  이명박|"이명박 출국금지"|"이명박 출국현장"|"이명박 바레인"|"이명박 대통령"|...
# 4 2017-11-13 06:08:00          nocutV|"노컷V"|"CBS"|"mbc"|"김장겸"|"해임"|"허일후"
#
#       views   likes  dislikes  comment_count  ... category_name_Howto & Style  \
# 0  156130.0  1422.0      40.0          272.0  ...                       False
# 1   76533.0   211.0      28.0          113.0  ...                       False
# 2  421409.0  5112.0     166.0          459.0  ...                       False
# 3  222850.0  2093.0     173.0         1219.0  ...                       False
# 4   84466.0  1094.0     109.0          450.0  ...                       False
#
#   category_name_Music category_name_News & Politics  \
# 0               False                         False
# 1               False                          True
# 2               False                         False
# 3               False                          True
# 4               False                          True
#
#   category_name_People & Blogs  category_name_Pets & Animals  \
# 0                         True                         False
# 1                        False                         False
# 2                         True                         False
# 3                        False                         False
# 4                        False                         False
#
#    category_name_Science & Technology category_name_Shows  \
# 0                               False               False
# 1                               False               False
# 2                               False               False
# 3                               False               False
# 4                               False               False
#
#    category_name_Sports  category_name_Trailers  category_name_Travel & Events
# 0                 False                   False                          False
# 1                 False                   False                          False
# 2                 False                   False                          False
# 3                 False                   False                          False
# 4                 False                   False                          False
#
# [5 rows x 35 columns]

# %% [markdown]
# ### 3. Modelado

# %%
#Creamos una lista con los nombres de las columnas codificadas
category_cols = [col for col in df_encoded.columns if col.startswith('category_name_')]

# %%
features = ['likes', 'dislikes', 'comment_count', 'like_ratio', 'comment_ratio', 'category_name_encoded']
target = 'views'

# %%
X = df_encoded[features]
y = df_encoded[target]

# %% [markdown]
# ### 3.1 Dividimos el dataset en entrenamiento y test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1280)

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (27520, 6)
# Shape of X_test: (6880, 6)
# Shape of y_train: (27520,)
# Shape of y_test: (6880,)

# %%
#iniciamos el modelo de Arboles de regresion
model_dt = DecisionTreeRegressor(random_state=42)

# %% [markdown]
# ### 3.2 Entrenamos

# %%
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
#Realizamos una predicción
y_pred_dt = model_dt.predict(X_test)
y_pred_dt
# Out:
# array([ 52344.   ,  19966.   , 625515.375, ...,  55095.   , 115413.   ,
#         17798.   ], shape=(6880,))

# %%
df_pred = pd.DataFrame(X_test)
df_pred = df_pred.assign(views=y_test)
df_pred = df_pred.assign(Pred = y_pred_dt.flatten().tolist())
df_pred.head(10)
# Out:
#           likes  dislikes  comment_count  like_ratio  comment_ratio  \
# 3043    179.000      11.0           66.0    0.003313       0.001222
# 1338    477.000       4.0           27.0    0.029038       0.001644
# 30835  8626.625     406.0         2160.0    0.013791       0.003453
# 25986   754.000     120.0          229.0    0.006184       0.001878
# 29807  6763.000     406.0         1054.0    0.016424       0.002560
# 11846     0.000       0.0           17.0    0.000000       0.000186
# 30775  3156.000      66.0          911.0    0.007873       0.002273
# 27141  4993.000     153.0          367.0    0.049163       0.003614
# 26503  1097.000      22.0          163.0    0.006969       0.001036
# 21476  8626.625     406.0         2160.0    0.013791       0.003453
#
#        category_name_encoded       views        Pred
# 3043                       3   54026.000   52344.000
# 1338                       3   16427.000   19966.000
# 30835                      3  625515.375  625515.375
# 25986                      8  121920.000  120525.000
# 29807                      8  411774.000  419021.000
# 11846                      8   91215.000  116468.000
# 30775                      8  400867.000  414910.000
# 27141                      8  101560.000  100168.000
# 26503                      3  157402.000  153410.000
# 21476                      8  625515.375  625515.375

# %% [markdown]
# ### 3.3 Resultados

# %%
# Creamos un gráfico de dispersión con la línea de regresión
sns.pairplot(df_pred, x_vars=['views'], y_vars='Pred', height=5, aspect=0.8,kind = 'reg',plot_kws={'line_kws': {'color': 'red'}})
plt.ylim(bottom=0)
# Out:
# (0.0, 656622.3185876732)

# %%
print('MAE-Error Absoluto Medio:', round(metrics.mean_absolute_error(y_test, y_pred_dt),2))
print('MSE-Error Cuadrático Medio:', round(metrics.mean_squared_error(y_test, y_pred_dt),2))
print('RMSE-Raiz del Error Cuadrático Medio:',round(np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt)),2))
# Out:
# MAE-Error Absoluto Medio: 5550.57
# MSE-Error Cuadrático Medio: 311646520.26
# RMSE-Raiz del Error Cuadrático Medio: 17653.51

# %%
r2_arbol = r2_score(y_test, y_pred_dt)
print(f"R² del modelo con Árbol de Regresión: {round(r2_arbol, 3)}")
# Out:
# R² del modelo con Árbol de Regresión: 0.992

# %%
r2_train = r2_score(y_train, model_dt.predict(X_train))
r2_test = r2_score(y_test, model_dt.predict(X_test))
print(f"R² en entrenamiento: {round(r2_train, 3)}")
print(f"R² en prueba: {round(r2_test, 3)}")
# Out:
# R² en entrenamiento: 0.997
# R² en prueba: 0.992

# %%
residuals_dt = y_test - y_pred_dt

plt.figure(figsize=(8, 5))
sns.scatterplot(x=y_pred_dt, y=residuals_dt, color='teal')
plt.axhline(0, color='red', linestyle='--')
plt.title('Gráfico de Residuales - Árbol de Regresión')
plt.xlabel('Valores Predichos (y_pred_dt)')
plt.ylabel('Residuales (y_test - y_pred)')
plt.grid(True)
plt.show()
# Out:
# C:\Users\rivas\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
importancias = pd.DataFrame({
    'Variable': X_train.columns,
    'Importancia': model_dt.feature_importances_
}).sort_values(by='Importancia', ascending=False)

# Gráfico
plt.figure(figsize=(8, 5))
sns.barplot(x='Importancia', y='Variable', data=importancias, palette='viridis')
plt.title('Importancia de las Variables en el Árbol de Regresión')
plt.xlabel('Importancia')
plt.ylabel('Variable')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\3057191323.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importancia', y='Variable', data=importancias, palette='viridis')

# %% [markdown]
# # Pregunta 1: ¿Qué categorías de videos son las de mayor tendencia?

# %%
# 1. ¿Qué categorías de videos son las de mayor tendencia?
plt.figure(figsize=(12,6))
sns.countplot(data=df, x='category_name', order=df['category_name'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Cantidad de videos por categoría')
plt.xlabel('Categoría')
plt.ylabel('Cantidad de videos')
plt.tight_layout()
plt.show()

#Tabla de conteo para el grafico
category_counts = df['category_name'].value_counts()
print("Cantidad de videos por categoría:")
print(category_counts)
# Out:
# Cantidad de videos por categoría:
# category_name
# Entertainment           9209
# News & Politics         7532
# People & Blogs          7023
# Film & Animation        2187
# Comedy                  2045
# Music                   1816
# Gaming                  1387
# Sports                   932
# Pets & Animals           732
# Howto & Style            557
# Education                484
# Shows                    165
# Autos & Vehicles         119
# Science & Technology     114
# Travel & Events           96
# Trailers                   2
# Name: count, dtype: int64

# %% [markdown]
# Los videos pertenecientes a la categoría de "Entretenimiento" son los má vistos con diferencia, seguidos de "Noticias y peliculas" y "Personas y blogs"

# %% [markdown]
# # Pregunta 2: ¿Qué categorías de videos son los que más gustan? ¿Y menos gustan?

# %%
# 2. ¿Qué categorías de videos son los que más gustan? ¿Y menos gustan?
likes_by_category = df.groupby('category_name')['likes'].sum().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(
    x=likes_by_category.values, 
    y=likes_by_category.index, 
    palette='viridis'
)

plt.title('Total de Likes por Categoría')
plt.xlabel('Número de Likes')
plt.ylabel('Categoría')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\2550304185.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# La categoría con más likes es la de "Entretenimiento", seguido por "Personas y blogs" y "Noticias y politicas", por otro lado la categoría con menos likes son "Trailers", "Shows" y "Atuos y vehiculos"

# %% [markdown]
# # Pregunta 3: Mejor ratio de “Me gusta” / “No me gusta”

# %%
# 3. Mejor ratio de “Me gusta” / “No me gusta”
df['like_dislike_ratio'] = df['likes'] / (df['dislikes'] + 1)  # +1 con esto evitamos la division por 0
ratio_by_category = df.groupby('category_name')['like_dislike_ratio'].mean().sort_values(ascending=False)
print("Categorías con mejor ratio de likes/dislikes:")
print(ratio_by_category)
# Out:
# Categorías con mejor ratio de likes/dislikes:
# category_name
# Pets & Animals          111.409911
# Music                    85.295414
# People & Blogs           58.431108
# Howto & Style            55.762570
# Autos & Vehicles         51.827343
# Gaming                   43.678596
# Comedy                   41.646433
# Education                40.988895
# Entertainment            39.335889
# Film & Animation         32.031989
# News & Politics          20.797772
# Science & Technology     20.609363
# Sports                   19.881882
# Travel & Events          18.486050
# Shows                    15.063732
# Trailers                  3.000000
# Name: like_dislike_ratio, dtype: float64

# %% [markdown]
# El mejor ratio de Me gusta/No me gusta pertece a la categoría de "Mascotas y Animales", que tiene en promedio 111 likes por cada dislike

# %% [markdown]
# # Pregunta 4: Mejor ratio de “Vistas” / “Comentarios”

# %%
# 4. Mejor ratio de “Vistas” / “Comentarios”
df['views_comments_ratio'] = df['views'] / (df['comment_count'] + 1)
ratio_views_comments = df.groupby('category_name')['views_comments_ratio'].mean().sort_values(ascending=False)
print("Categorías con mejor ratio de vistas/comentarios:")
print(ratio_views_comments)
# Out:
# Categorías con mejor ratio de vistas/comentarios:
# category_name
# Science & Technology    41026.639106
# Trailers                 8324.750000
# Gaming                   7380.988271
# Comedy                   6089.637345
# Education                4405.693351
# Howto & Style            4101.112132
# News & Politics          3744.492206
# Sports                   3658.402796
# People & Blogs           3118.525119
# Entertainment            2554.242715
# Film & Animation         2181.811263
# Music                    1371.267820
# Autos & Vehicles         1171.972702
# Shows                     958.213461
# Pets & Animals            635.658282
# Travel & Events           607.783428
# Name: views_comments_ratio, dtype: float64

# %% [markdown]
# El mejor ratio de Vistas/Comentarios pertece a la categoría de "Ciencia y Tecnologia", que tiene en promedio 41026 vistas por cada comentario

# %% [markdown]
# # Pregunta 5: ¿Cómo ha cambiado el volumen de videos en tendencia a lo largo del tiempo?

# %%
# 5. ¿Cómo ha cambiado el volumen de videos en tendencia a lo largo del tiempo?
trend_over_time = df.groupby(df['publish_time'].dt.to_period('M')).size()

# Revisa los resultados en consola
print("\nVolumen de videos por mes:")
print(trend_over_time)

# Grafica
trend_over_time.plot(kind='line', marker='o', figsize=(12, 6))
plt.title('Volumen de Videos en Tendencia a lo Largo del Tiempo (por Fecha de Publicación)')
plt.xlabel('Mes')
plt.ylabel('Número de Videos')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Volumen de videos por mes:
# publish_time
# 2011-09       3
# 2014-09       1
# 2014-10       1
# 2015-03       1
# 2015-04       2
# 2016-02       6
# 2017-02       3
# 2017-06       2
# 2017-09       7
# 2017-10       2
# 2017-11    3362
# 2017-12    5183
# 2018-01    4770
# 2018-02    4581
# 2018-03    5234
# 2018-04    3934
# 2018-05    5201
# 2018-06    2107
# Freq: M, dtype: int64

# %% [markdown]
# Se aprecio que desde fines de 2017 la gente del pais de Corea del sur aumento considerablemente la cantidad de videos que subían a Youtube

# %% [markdown]
# # Pregunta 6: ¿Qué Canales son tendencia más frecuentemente? ¿Y cuáles menos?

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

videos_por_canal = df.groupby('channel_title').size().reset_index(name='cantidad_videos_tendencia')
top_5 = videos_por_canal.sort_values(by='cantidad_videos_tendencia', ascending=False).head(5)

bottom_5 = videos_por_canal[videos_por_canal['cantidad_videos_tendencia'] > 0].sort_values(by='cantidad_videos_tendencia').head(5)

#Gráfico Top 5
plt.figure(figsize=(12,5))
sns.barplot(data=top_5, x='cantidad_videos_tendencia', y='channel_title', palette='Greens_d')
plt.title('Top 5 canales con más videos en tendencia')
plt.xlabel('Cantidad de videos en tendencia')
plt.ylabel('Canal')
plt.tight_layout()
plt.show()

#Gráfico Bottom 5
plt.figure(figsize=(12,5))
sns.barplot(data=bottom_5, x='cantidad_videos_tendencia', y='channel_title', palette='Reds_d')
plt.title('Top 5 canales con menos videos en tendencia (con al menos 1 video)')
plt.xlabel('Cantidad de videos en tendencia')
plt.ylabel('Canal')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\3674372352.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5, x='cantidad_videos_tendencia', y='channel_title', palette='Greens_d')
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\3674372352.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom_5, x='cantidad_videos_tendencia', y='channel_title', palette='Reds_d')

# %% [markdown]
# # Pregunta 7: Estados con mayor número de vistas, likes y dislikes

# %%
# 7. Estados con mayor número de vistas, likes y dislikes
state_agg = df.groupby('state')[['views', 'likes', 'dislikes']].sum()
views_sorted = state_agg.sort_values(by='views', ascending=False).head(10)
likes_sorted = state_agg.sort_values(by='likes', ascending=False).head(10)
dislikes_sorted = state_agg.sort_values(by='dislikes', ascending=False).head(10)

# Estilo
sns.set_style('whitegrid')
plt.figure(figsize=(18, 6))

# Gráfico: Vistas
plt.subplot(1, 3, 1)
sns.barplot(
    y=views_sorted.index,
    x=views_sorted['views'],
    palette='Blues',
    ci=None  # Quita IC
)
plt.title('Top 10 Estados por Vistas')
plt.xlabel('Vistas')
plt.ylabel('Estado')

# Gráfico: Likes
plt.subplot(1, 3, 2)
sns.barplot(
    y=likes_sorted.index,
    x=likes_sorted['likes'],
    palette='Greens',
    ci=None
)
plt.title('Top 10 Estados por Likes')
plt.xlabel('Likes')
plt.ylabel('')

# Gráfico: Dislikes
plt.subplot(1, 3, 3)
sns.barplot(
    y=dislikes_sorted.index,
    x=dislikes_sorted['dislikes'],
    palette='Reds',
    ci=None
)
plt.title('Top 10 Estados por Dislikes')
plt.xlabel('Dislikes')
plt.ylabel('')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\285821151.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\285821151.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\285821151.py:25: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\285821151.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\285821151.py:37: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# C:\Users\rivas\AppData\Local\Temp\ipykernel_27904\285821151.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Pregunta 8: ¿Los videos en tendencia reciben más comentarios positivos?

# %%
# 8. ¿Los videos en tendencia reciben más comentarios positivos?
# Asegurarnos de que no haya divisiones por 0 en ratios si no lo hiciste antes
df['like_ratio'] = df['likes'] / (df['views'] + 1)
df['comment_ratio'] = df['comment_count'] / (df['views'] + 1)

# Agrupar por categoría
grouped = df.groupby('category_name')[['like_ratio', 'comment_ratio']].mean()

# Ordenar por like_ratio para ver quiénes tienen mejor recepción
grouped_sorted = grouped.sort_values(by='like_ratio', ascending=False)

# Mostrar resultado
print("¿Qué categorías reciben más comentarios positivos (likes + comments)?")
print(grouped_sorted)
# Out:
# ¿Qué categorías reciben más comentarios positivos (likes + comments)?
#                       like_ratio  comment_ratio
# category_name
# Autos & Vehicles        0.029973       0.004357
# Pets & Animals          0.028344       0.005155
# Music                   0.027145       0.004266
# Education               0.025336       0.004087
# Howto & Style           0.022680       0.003924
# News & Politics         0.022290       0.004471
# Gaming                  0.018377       0.007003
# People & Blogs          0.017613       0.003351
# Entertainment           0.016346       0.003831
# Comedy                  0.015534       0.004196
# Science & Technology    0.014124       0.004165
# Film & Animation        0.011735       0.003909
# Travel & Events         0.009164       0.002804
# Sports                  0.006533       0.002450
# Shows                   0.004292       0.002877
# Trailers                0.000187       0.000062

# %% [markdown]
# No, solo porque un video pertenezca a una categoría en tendencia significa que va a recibir ocmentarios positivos, por ejemplo "Entretenimiento" es la categoría con mayor tendencia, sin embargo es la ocatava categoría más baja en relación al ratio de likes y de comentarios

# %% [markdown]
# # Pregunta 9: ¿Es factible predecir el número de “Vistas” o “Me gusta” o “No me gusta”?

# %%
sns.pairplot(df_pred, x_vars=['views'], y_vars='Pred', height=5, aspect=0.8,kind = 'reg',plot_kws={'line_kws': {'color': 'red'}})
plt.ylim(bottom=0)
# Out:
# (0.0, 656623.69681609)

# %% [markdown]
# Claro que es factible, con nuestro modelo entrenado podemos preveer cuales videos conseguiran la mayor cantidad de vistas y con esta información una persona podría dedicarse a crear contenido de esa categoría con el fin de ganar dinero
